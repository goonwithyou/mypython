# %% [markdown]
# ##  3.2.2 Legend guide
# ---
# - Controlling the legend entries
# - Creating artists specifically for adding to the legend (aka. Proxy artists)
# - Legend location
# - Multiple legends on the same Axes
# - Implementing a custom legend handler
#
# ## 3.2.3 Artist tutorial
# ---
# - Customizing your objects
# - Object containers
# - Figure containers
# - Axes containers
# - Axis containers
# - Tick containers
#
# ## 3.2.4 Customizing Figure Layouts Using GridSpec and Other Function
# ---
# - Basic Quickstart Guide
# - Fine Adjustments to a Gridspec Layout
# - GridSpec using SubplotSpec
# - A Complex Nested GridSpec using SubplotSpec
#
# ## 3.2.5 Tight Layout guide
# ---
# - Simple Example
# - Caveats
# - Use with GridSpec
# - Use with AxesGrid1
# - Colorbar
#
# ## 3.2.6 Constrained Layout Guide
# ---
# - Simple Example
# - Colorbars
# - Suptitle
# - Legends
# - Padding and Spacing
# - Spacing with colorbars
# - rcParams
# - Use with GridSpec
# - Manually setting axes positions
# - Limitations
# - Incompatible functions
# - Other Caveats
# - Debugging
# - Notes on the algorithm
# - Figure layout
# - Simple case: one Axes
# - Simple case: two Axes
# - Two Axes and colorbar
# - Colorbar associate with a Gridspec
# - Uneven sized Axes
# - Empty gridspec slots
# - other notes

# %%
# %matplotlib inline

# %% [markdown]
# import matplotlib.pyplot as plt
# import numpy as np

# %% [markdown]
# ## Legend guide
# ---
# - Controlling the legend entries
# - Creating artists specifically for adding to the legend (aka. Proxy artists)
# - Legend location
# - Multiple legends on the same Axes
# - Implementing a custom legend handler
#
# ## Controlling the legend entries
# ---

# %%
import matplotlib.pyplot as plt

line_up, = plt.plot([1,2,3], label='label 2')
line_down, = plt.plot([3,2,1], label='label 1')
plt.legend([line_up, line_down], ['Line Up', 'Line Down'])
plt.show()

# %% [markdown]
# ## Creating artists specifically for adding to the legend(aka.Proxy artists)
# ---

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

red_patch = mpatches.Patch(color='red', label='The red data')
plt.legend(handles=[red_patch])

plt.show()

# %%
import matplotlib.lines as mlines
import matplotlib.pyplot as plt

blue_line = mlines.Line2D([], [], color='blue', marker='*',
markersize=15, label='Blue stars')
plt.legend(handles=[blue_line])
plt.show()

# %%
plt.subplot(211)
plt.plot([1, 2, 3], label="test1")
plt.plot([3, 2, 1], label="test2")

plt.legend(bbox_to_anchor=(0., 1.2,1,0.1),
ncol=2,  borderaxespad=0., mode='expand')
# bbox_to_anchor四个参数中的后两个要配合mode=expand一起使用
plt.subplot(221)
plt.plot([1, 2, 3], label="test1")
plt.plot([3, 2, 1], label="test2")
# Place a legend to the right of this smaller subplot.
plt.legend(bbox_to_anchor=(-0.5, 1.01), loc=3, borderaxespad=0.)
plt.show()

# %%
line1, = plt.plot([1, 2, 3], label="Line 1", linestyle='--')
line2, = plt.plot([3, 2, 1], label="Line 2", linewidth=4)

first_legend = plt.legend(handles=[line1], loc=1)
ax = plt.gca().add_artist(first_legend)

plt.legend(handles=[line2], loc=4)
plt.show()

# %% [markdown]
# ## Legend Handles
# ---

# %%
from matplotlib.legend_handler import HandlerLine2D

line1, = plt.plot([3, 2, 1], marker='o', label='Line 1')
line2, = plt.plot([1, 2, 3], marker='o', label='Line 2')

plt.legend(handler_map={line1: HandlerLine2D(numpoints=4)})

# %%
from numpy.random import randn
z = randn(10)
red_dot, = plt.plot(z, "ro", markersize=15)

white_cross, = plt.plot(z[:5], "w+", markeredgewidth=3, markersize=15)

plt.legend([red_dot, (red_dot, white_cross)], ["Attr A", "Attr A+B"], loc=2)

# %%
from matplotlib.legend_handler import HandlerLine2D, HandlerTuple
p1, = plt.plot([1, 2.5, 3], 'r-d')
p2, = plt.plot([3, 2, 1], 'k-o')

l = plt.legend([(p1, p2)], ['Two keys'], numpoints=1,
handler_map={tuple: HandlerTuple()})

# %% [markdown]
# # 3.2.3 Artist tutorial
# ---
#     add_axes([left, bottom , width, height])
# - Customizing your objects
# - Object containers
# - Figure containers
# - Axes containers
# - Axis containers
# - Tick containers

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(2,1,1)

fig2 = plt.figure()
ax2 = fig2.add_axes([0.15, 0.1, 0.7, 0.3])

import numpy as np
t = np.arange(0,1,0.01)
s = np.sin(2*np.pi*t)
line, = ax.plot(t, s, color='blue', lw=2)

xtext = ax.set_xlabel('my xdata')
ytext = ax.set_ylabel('my ydata')

# %%
fig = plt.figure()
fig.subplots_adjust(top=0.8)
ax1 = fig.add_subplot(211)
ax1.set_ylabel('volts')
ax1.set_title('a sine wave')

t = np.arange(0,1,0.01)
s = np.sin(2*np.pi*t)
line, = ax1.plot(t, s, color='blue', lw=2)

np.random.seed(19680801)

ax2 = fig.add_axes([0.15, 0.1, 0.7, 0.3])
n, bins, patches = ax2.hist(np.random.randn(1000), 50, facecolor='yellow',
                           edgecolor='yellow')
ax2.set_xlabel('time (s)')
plt.show()

# %% [markdown]
# ## Customizing your objects
# ---

# %%
import matplotlib as mpl
mpl.artist.getp(fig.patch)
# Out:
#     aa = False
#     agg_filter = None
#     alpha = None
#     animated = False
#     antialiased or aa = False
#     axes = None
#     bbox = Bbox(x0=0.0, y0=0.0, x1=1.0, y1=1.0)
#     capstyle = butt
#     children = []
#     clip_box = None
#     clip_on = True
#     clip_path = None
#     contains = None
#     data_transform = BboxTransformTo(TransformedBbox(Bbox([[0.0, 0.0], ...
#     ec = (1.0, 1.0, 1.0, 0.0)
#     edgecolor or ec = (1.0, 1.0, 1.0, 0.0)
#     extents = Bbox(x0=0.0, y0=0.0, x1=432.0, y1=288.0)
#     facecolor or fc = (1.0, 1.0, 1.0, 0.0)
#     fc = (1.0, 1.0, 1.0, 0.0)
#     figure = Figure(432x288)
#     fill = True
#     gid = None
#     hatch = None
#     height = 1
#     joinstyle = miter
#     label =
#     linestyle or ls = solid
#     linewidth or lw = 0.0
#     ls = solid
#     lw = 0.0
#     patch_transform = CompositeGenericTransform(BboxTransformTo(Bbox([[0...
#     path = Path(array([[ 0.,  0.],        [ 1.,  0.],        ...
#     path_effects = []
# ...

# %% [markdown]
# ## Figure container
# ---

# %%
print(mpl.figure.Figure().patch)
# Out:
# Rectangle(0,0;1x1)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(211)
ax2 = fig.add_axes([0.1, 0.1, 0.7, 0.3])
print(fig.axes)

for ax in fig.axes:
    ax.grid(True)
# Out:
# [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4b0c461780>, <matplotlib.axes._axes.Axes object at 0x7f4b0c3e95f8>]

# %%
import matplotlib.lines as lines
fig = plt.figure()
l1 = lines.Line2D([0, 1], [0, 1], transform=fig.transFigure, figure=fig)
l2 = lines.Line2D([0, 1], [1, 0], transform=fig.transFigure, figure=fig)
fig.lines.extend([l1, l2])
plt.show()

# %% [markdown]
# ## Axes container
# ---

# %%
ax = fig.add_subplot(111)
rect = ax.patch
rect.set_facecolor('green')

x, y = np.random.rand(2, 100)
line, = ax.plot(x, y, '-', color='blue', lw=2)

plt.show()

# %% [markdown]
# ## Axis container
# ---

# %%
fig, ax = plt.subplots()
axis = ax.xaxis
axis.get_ticklocs()

tl = axis.get_ticklabels()
for i in tl:
    print(i)
# Out:
# Text(0,0,'')
# Text(0,0,'')
# Text(0,0,'')
# Text(0,0,'')
# Text(0,0,'')
# Text(0,0,'')

# %%
list(axis.get_ticklines())

# %% [markdown]
# ## Tick containers
# ---

# %%
import matplotlib.ticker as ticker
# Fixing random state for reproducibility
np.random.seed(19680801)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(100*np.random.rand(20))
formatter = ticker.FormatStrFormatter('$%b.2f')
ax.yaxis.set_major_formatter(formatter)
for tick in ax.yaxis.get_major_ticks():
    tick.label1On = False
    tick.label2On = True
    tick.label2.set_color('green')
plt.show()

# %% [markdown]
# # 3.2.4 Customizing Figure Layouts Using GridSpec and Other Function
# ---
# - Basic Quickstart Guide
# - Fine Adjustments to a Gridspec Layout
# - GridSpec using SubplotSpec
# - A Complex Nested GridSpec using SubplotSpec

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
fig1, f1_axes = plt.subplots(ncols=2, nrows=2)
fig1.tight_layout()

# %%
fig2 = plt.figure()
spec2 = gridspec.GridSpec(ncols=2, nrows=2)
f2_ax1 = fig2.add_subplot(spec2[0, 0])
f2_ax2 = fig2.add_subplot(spec2[0, 1])
f2_ax3 = fig2.add_subplot(spec2[1, 0])
f2_ax4 = fig2.add_subplot(spec2[1, 1])
fig2.tight_layout()

# %%
fig3 = plt.figure()
spec3 = gridspec.GridSpec(ncols=3, nrows=3)
anno_opts = dict(xy=(0.5, 0.5), xycoords='axes fraction',
va='center', ha='center')
fig3.add_subplot(spec3[0, 0]).annotate('GridSpec[0, 0]', **anno_opts)
fig3.add_subplot(spec3[0, 1:]).annotate('GridSpec[0, 1:]', **anno_opts)
fig3.add_subplot(spec3[1:, 0]).annotate('GridSpec[1:, 0]', **anno_opts)
fig3.add_subplot(spec3[1:, 1:]).annotate('GridSpec[1:, 1:]', **anno_opts)

fig3.tight_layout()

# %% [markdown]
# # 3.2.5 Tight Layout guide
# ---
# - Simple Example
# - Caveats
# - Use with GridSpec
# - Use with AxesGrid1
# - Colorbar

# %% [markdown]
# # 3.2.6 Constrained Layout Guide
# ---
# - Simple Example
# - Colorbars
# - Suptitle
# - Legends
# - Padding and Spacing
# - Spacing with colorbars
# - rcParams
# - Use with GridSpec
# - Manually setting axes positions
# - Limitations
# - Incompatible functions
# - Other Caveats
# - Debugging
# - Notes on the algorithm
# - Figure layout
# - Simple case: one Axes
# - Simple case: two Axes
# - Two Axes and colorbar
# - Colorbar associate with a Gridspec
# - Uneven sized Axes
# - Empty gridspec slots
# - other notes

# %% [markdown]
# ##
