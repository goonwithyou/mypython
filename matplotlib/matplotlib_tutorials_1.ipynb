# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
# !../matplotlib/stinkbug.png
# Out:
# : not found
# ../matplotlib/stinkbug.png: 2: ../matplotlib/stinkbug.png: : not found
# ../matplotlib/stinkbug.png: 3: ../matplotlib/stinkbug.png: Syntax error: ")" unexpected

# %%
img = mpimg.imread('../matplotlib/stinkbug.png')
print(img)
# Out:
# [[[ 0.40784314  0.40784314  0.40784314]
#   [ 0.40784314  0.40784314  0.40784314]
#   [ 0.41176471  0.41176471  0.41176471]
#   ...,
#   [ 0.42745098  0.42745098  0.42745098]
#   [ 0.42745098  0.42745098  0.42745098]
#   [ 0.42745098  0.42745098  0.42745098]]
#
#  [[ 0.41176471  0.41176471  0.41176471]
#   [ 0.41176471  0.41176471  0.41176471]
#   [ 0.41176471  0.41176471  0.41176471]
#   ...,
#   [ 0.42745098  0.42745098  0.42745098]
#   [ 0.42745098  0.42745098  0.42745098]
#   [ 0.42745098  0.42745098  0.42745098]]
#
#  [[ 0.41568628  0.41568628  0.41568628]
#   [ 0.41568628  0.41568628  0.41568628]
#   [ 0.41960785  0.41960785  0.41960785]
#   ...,
#   [ 0.43137255  0.43137255  0.43137255]
#   [ 0.43137255  0.43137255  0.43137255]
#   [ 0.43137255  0.43137255  0.43137255]]
#
#  ...,
#  [[ 0.43529412  0.43529412  0.43529412]
#   [ 0.43529412  0.43529412  0.43529412]
#   [ 0.43921569  0.43921569  0.43921569]
#   ...,
#   [ 0.45882353  0.45882353  0.45882353]
# ...

# %%
imgplot = plt.imshow(img)

# %%
lum_img = img[:, :, 0]
plt.imshow(lum_img)

# %%
plt.imshow(lum_img, cmap="hot")

# %%
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('nipy_spectral')

# %%
imgplot = plt.imshow(lum_img)
plt.colorbar()

# %%
plt.hist(lum_img.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k')
plt.show()

# %%
imgplot = plt.imshow(lum_img, clim=(0.0, 0.7))

# %%
fig = plt.figure()
a = fig.add_subplot(1, 2, 1)
imgplot = plt.imshow(lum_img)
a.set_title('Before')
plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')
a = fig.add_subplot(1, 2, 2)
imgplot = plt.imshow(lum_img)
imgplot.set_clim(0.0, 0.7)
a.set_title('After')
plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')

# %%
from PIL import Image

# %%
img = Image.open('../matplotlib/stinkbug.png')
img.thumbnail((64, 64), Image.ANTIALIAS) # antialise, resize image in-place
imgplot = plt.imshow(img)

# %%
imgplot = plt.imshow(img, interpolation='nearest')

# %%
imgplot = plt.imshow(img, interpolation='bicubic')

# %% [markdown]
# # pyplot

# %% [markdown]
# ## General Concepts
# ---
# 1. **Figure**. The figure keeps track of all the child **Axes**, a smattering of special **artists**(titles, figure legends, etc), and the **canvas**.
#     - a figure can have any number of **Axes**, but to be useful shoule have at least one.
# 2. **Axes**. this is what you think of as a plot, it is the region of the image with data space.
#     - a given figure can contain many **Axes** object, but a given **Axes** object can only be in one **Figure**.
#     - the Axes contains two (or three) **Axis** objects which take care of the data limits.
#     - each Axes has a **title**, an **x-label**, and a **y-label**.
# 3. **Axis**. the take care of setting the **graph limit** and **generating the ticks** and **ticklabels**.
#     - the location of ticks is determined by a **Locator** object and the ticklabel string are formatted by a **Formatter**.
# 4. **artist**. basically everything you can see on the figure is an artist(even the **Figure, Axes, Axis objects**).
#     - this include **text** object, **Line2D** objects, **collection** objects, **Patch** objects.
#     - when the figure is rendered, all of the artists are drawn to the **canvas**.
#     - Most **artists** are tied to an **Axes**. an artist cannot be shared by multiple Axes.

# %% [markdown]
# ## Types of inputs to plotting function
# ---
# all of plotting function expect `np.array` or `np.ma.masked_array` as input. pandas object and np.matrix should convert to np.array objects.

# %%
import numpy as np
import pandas as pd

# %%
# pandas object
a = pd.DataFrame(np.random.rand(4, 5), columns = list('abcde'))
a_asndarray = a.values
# np.matrix
b = np.matrix([[1, 2], [3, 4]])
b.asarray = np.asarray(b)

# %% [markdown]
# ## Matplotlib, pyplot, pylab?
# ---
# - matplolib is the whole package.
# - matplotlib.pyplot is a module in matplotlib
# - pylab is a module that gets installed alongside matplotlib.
#
# ## pyplot
# ---
# pyplot provides the state-machine interface to the underlying object-oriented plotting library.
#
#     - the state machine implicitly and automatically crates figures and axes to achieve the desired plot.

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title('simple plot')

plt.legend()

plt.show()

# %% [markdown]
# ## Coding Styles
# ---

# %%
# 通过figure创建plot, plt.figure().add_subplot()
x = np.arange(0, 10, 0.2)
y = np.sin(x)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y)
plt.show()

# %%
# 直接用plot
plt.plot(x, y)
plt.show()

# %%
# 
def my_plotter(ax, data1, data2, param_dict):
    out = ax.plot(data1, data2, **param_dict)
    return out


data1, data2, data3, data4 = np.random.randn(4, 100)
fig, ax = plt.subplots(1, 1)
my_plotter(ax, data1, data2, {'marker': 'x'})

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data3, data4, {'marker': 'o'})
my_plotter(ax3, data3, data4, {'marker': 'x'})

# %% [markdown]
# # 3.1.6 Pyplot tutorial
# ---
# ## INtro to pyplot
# ---

# %% [markdown]
# > 当plot接收的是一维数组，则默认为ｙ值，并生成等同长度的ｘ值，range(len(y))

# %%
plt.plot([1,2,3,4])
plt.ylabel('xxxxx')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# - the default format string is 'b-', which is solid blue line.
# - we can use `plt.axis([xmin, xmax, ymin, ymax])`,to define axis data limit

# %% [markdown]
# > plot servel lines with different fromat styles in one commend using arrays.

# %%
t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# ## Plotting with keyword string
# ---

# %% [markdown]
# > use `data` keyword argument to plot with the string corresponding to these variables.

# %%
data = {
    'c': np.random.randint(0, 50, 50),
#     'c': [10] * 50,
    'd': np.random.randn(50),
#     'd': [100] * 50,
    'a': np.arange(50)
}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %% [markdown]
# ## Plotting with categorical variables
# ---

# %% [markdown]
# > create a plot using categorical variables.(version 2.2.2)

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]
x = range(len(names))
data = {'1': 'ndnd', }

plt.figure(1, figsize=(9, 3))

plt.subplot(131)
plt.bar(x, values, tick_label=names)
plt.subplot(132)
plt.scatter(x, values)
plt.xticks(x, names)
plt.subplot(133)
plt.plot(x, values)
plt.xticks(x, names)


plt.suptitle('categorical plotting')
plt.show()

# %% [markdown]
# ## Controlling line properties
# ---
# > `linewidth, dash style, antialiased`

# %% [markdown]
# - Use keyword args:

# %%
plt.plot(x, y, linewidth=5.0)
plt.show()

# %% [markdown]
# - use the setter methods of a line2d instance.

# %%
line, = plt.plot(x, y, '-')
line.set_antialiased(False) # turn off　抗锯齿

# %% [markdown]
# - use the `setp()`(set properties) command.

# %%
lines = plt.plot([1,2,3], [4,5,6], [3,4,5],[7,8,9])
plt.setp(lines, color='r', linewidth=3)
# Out:
# [None, None, None, None]

# %%
lines = plt.plot([1,2,3])
plt.setp(lines)
# Out:
#   agg_filter: unknown
#   alpha: float (0.0 transparent through 1.0 opaque)
#   animated: [True | False]
#   antialiased or aa: [True | False]
#   axes: an :class:`~matplotlib.axes.Axes` instance
#   clip_box: a :class:`matplotlib.transforms.Bbox` instance
#   clip_on: [True | False]
#   clip_path: [ (:class:`~matplotlib.path.Path`, :class:`~matplotlib.transforms.Transform`) | :class:`~matplotlib.patches.Patch` | None ]
#   color or c: any matplotlib color
#   contains: a callable function
#   dash_capstyle: ['butt' | 'round' | 'projecting']
#   dash_joinstyle: ['miter' | 'round' | 'bevel']
#   dashes: sequence of on/off ink in points
#   drawstyle: ['default' | 'steps' | 'steps-pre' | 'steps-mid' | 'steps-post']
#   figure: a :class:`matplotlib.figure.Figure` instance
#   fillstyle: ['full' | 'left' | 'right' | 'bottom' | 'top' | 'none']
#   gid: an id string
#   label: string or anything printable with '%s' conversion.
# ...

# %% [markdown]
# ## Working with multiple figures and axes
# ---
#     gcf() # get current figure
#     gca() # get current axes
#
#     clf() # clear the current figure
#     cla() # clear the current axes
#
#     close()

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0., 5., 0.1)
t2 = np.arange(0., 5., .02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
dd
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4fff478208>
# ...

# %%
plt.figure(1)
plt.subplot(211)
plt.plot([1,2,3])
plt.subplot(212)
plt.plot([4,5,6])

plt.figure(2)
plt.plot([2,3,4])

plt.figure(1)
plt.subplot(211)
plt.title('this is 211')

plt.show()

# %% [markdown]
# ## Working with text
# ---
#     text() # add text in an arbitrary location
#     xlabel()
#     ylabel()
#     title()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

n, bins, pathches = plt.hist(x, 50, normed=1, facecolor='g', alpha=0.75)

plt.xlabel('Smarts', fontsize=14, color='red')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, 0.025, r'$\mu=100, \ \sigma=15$') # TeX use $$
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# ## Annotating text
# ---

# %%
ax = plt.subplot(111)

t = np.arange(0.,5., .01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5), 
            arrowprops=dict(facecolor='red', shrink=0.05))

plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# ## Logarithmic and other nonlinear axes
# ---

# %%
from matplotlib.ticker import NullFormatter


np.random.seed(19680801)

y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

plt.figure(1)

plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

plt.subplot(223)
plt.plot(x, y - np.mean(y))
plt.yscale('symlog', linthreshy=0.01)
plt.title('symlog')
plt.grid(True)

plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)

plt.gca().yaxis.set_minor_formatter(NullFormatter())

plt.subplots_adjust(top=0.92, bottom=0.08, 
                    left=0.10, right = 0.95, hspace=0.4,
                    wspace=0.35)

plt.show()

# %% [markdown]
# # 3.1.7 The Lifecycle of a Plot
# ---

# %%
data = {'Barton LLC': 109438.50,
'Frami, Hills and Schmidt': 103569.59,
'Fritsch, Russel and Anderson': 112214.71,
'Jerde-Hilpert': 112591.43,
'Keeling LLC': 100934.30,
'Koepp Ltd': 103660.54,
'Kulas Inc': 137351.96,
'Trantow-Barrows': 123381.38,
'White-Trantow': 135841.99,
'Will LLC': 104437.60}
group_data = list(data.values())
group_names = list(data.keys())
group_mean = np.mean(group_data)

# %%
fig, ax = plt.subplots()
ax.barh(range(len(group_names)), group_data, tick_label=group_names) # , tick_label=group_names
# ax.set_yticklabels(group_names)
plt.show()

# %% [markdown]
# ## Controlling the style
# ---
#     plt.rcParams.update({'figure.autolayout': True})
#
#     fig, ax = plt.subplots()
#     labels = ax.get_xticklabels()
#     plt.setp(labels, ratation=45, horizontalalignment='right')

# %%
print(plt.style.available)
# Out:
# ['seaborn-ticks', 'seaborn-paper', 'seaborn-colorblind', 'seaborn-pastel', 'classic', 'seaborn-poster', 'ggplot', 'seaborn-dark', 'seaborn', 'bmh', 'fivethirtyeight', 'seaborn-notebook', 'seaborn-talk', 'seaborn-dark-palette', 'dark_background', 'seaborn-bright', 'seaborn-whitegrid', 'seaborn-white', 'seaborn-deep', 'grayscale', 'seaborn-darkgrid', '_classic_test', 'seaborn-muted']

# %%
plt.style.use('fivethirtyeight')
fig, ax = plt.subplots()
ax.barh(range(len(group_names)), group_data, tick_label=group_names)
plt.show()

# %%
fig, ax = plt.subplots()
ax.barh(range(len(group_names)), group_data, tick_label=group_names)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
plt.show()

# %%
plt.rcParams.update({'figure.autolayout': False})

fig, ax = plt.subplots()
# fig.set_tight_layout(False)
ax.barh(range(len(group_names)), group_data, tick_label=group_names)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
plt.show()

# %%
fig, ax = plt.subplots()
# fig.set_tight_layout(False)
ax.barh(range(len(group_names)), group_data, tick_label=group_names)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
      title='Company Revenue')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.barh(range(len(group_names)), group_data, tick_label=group_names)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
      title='Company Revenue')
plt.show()

# %%
from matplotlib.ticker import FuncFormatter

def currency(x, pos):
    """The two args are the value and tick position"""
    if x >= 1e6:
        s = '${:1.1f}M'.format(x*1e-6)
    else:
        s = '${:1.0f}K'.format(x*1e-3)
    return s

formatter = FuncFormatter(currency)

fig, ax = plt.subplots(figsize=(8, 4))
ax.barh(range(len(group_names)), group_data, tick_label=group_names)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
      title='Company Revenue')
ax.xaxis.set_major_formatter(formatter)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.barh(range(len(group_names)), group_data, tick_label=group_names)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')

ax.axvline(group_mean, ls='--', color='r')

for group in [3, 5, 8]:
    ax.text(14500, group, 'New Company', 
            fontsize=10, verticalalignment='center')

ax.title.set(y=1.05)

ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
      title='Company Revenue')
ax.xaxis.set_major_formatter(formatter)
ax.set_xticks([0, 25e3, 50e3, 75e3, 100e3, 125e3])
fig.subplots_adjust(right=.8)

plt.show()

# %% [markdown]
# ## Saving out plot
# ---
# To see a list of available option, use:

# %%
print(fig.canvas.get_supported_filetypes())
# Out:
# {'ps': 'Postscript', 'eps': 'Encapsulated Postscript', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format'}

# %%
fig.savefig('sales.png', transparent=False, dpi=80, bbox_inches='tight')

# %% [markdown]
# # 3.2 Intermediate
# ---
# ## 3.2.1 Styling with cycler
# ---

# %%
from cycler import cycler
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2 * np.pi, 50)
offsets = np.linspace(0, 2 * np.pi, 4, endpoint=False)
yy = np.transpose([np.sin(x + phi) for phi in offsets])
yy.shape
# Out:
# (50, 4)

# %%
default_cycler = cycler('color', ['r', 'g', 'b', 'y']) + \
                    cycler('linestyle', ['-', '--', ':', '-.'])

custom_cycler = cycler('color', ['c', 'm', 'y', 'k']) + \
                    cycler('lw', [1, 2, 3, 4])
    
    
plt.rc('lines', linewidth=4)
plt.rc('axes', prop_cycle=default_cycler)

fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(yy)
ax1.set_title('set default color cycle to rgby')

ax2.set_prop_cycle(custom_cycler)
ax2.plot(yy)
ax2.set_title('set axes color cycle to cmyk')

fig.subplots_adjust(hspace=0.5)
plt.show()

# %% [markdown]
# ## Cycling through multiple properties
# ---
#     cycler(*args, **kwargs)
#     cycler(arg)
#     cycler(label1=iter1[, label2=iter2])
#     cycler(label, iter)

# %%
custom_cycler = cycler('color', ['c', 'm', 'y', 'k']) + \
                    cycler('lw', [1, 2, 3, 4])

for i in custom_cycler:
    print(i)
# Out:
# {'color': 'c', 'lw': 1}
# {'color': 'm', 'lw': 2}
# {'color': 'y', 'lw': 3}
# {'color': 'k', 'lw': 4}

# %%
custom_cycler2 = cycler(color=list('cmy')) * \
                    cycler(lw=[1, 2, 3])

for i in custom_cycler2:
    print(i)
# Out:
# {'color': 'c', 'lw': 1}
# {'color': 'c', 'lw': 2}
# {'color': 'c', 'lw': 3}
# {'color': 'm', 'lw': 1}
# {'color': 'm', 'lw': 2}
# {'color': 'm', 'lw': 3}
# {'color': 'y', 'lw': 1}
# {'color': 'y', 'lw': 2}
# {'color': 'y', 'lw': 3}
